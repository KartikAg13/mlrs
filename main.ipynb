# %% [markdown]
# ### This a comparison between python and rust

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
data = pd.read_csv(filepath_or_buffer='tests/fixtures/sample.csv')

# %%
data.head()
# Out:
#    id      name  age     salary active  ...  value    status    tag priority notes
# 0   1      lrwd   47  177466.63  false  ...   -inf  inactive      1        3   123
# 1   2     godyt   50  113045.92     no  ...    NaN   pending  alpha     high  true
# 2   3   ytjskvo   24   65651.67      1  ...   -inf    active   beta        3   NaN
# 3   4   zxivymd   34   32027.05   true  ...    NaN  inactive   true        1  true
# 4   5  stzsudeq   22   83032.65      0  ...    NaN   pending    yes        3   123
#
# [5 rows x 20 columns]
